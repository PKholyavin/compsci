# %% [markdown]
# ### Автоматическая проверка орфографии
#
# Конечная цель &ndash; написать код, который будет определять, написано ли слово правильно или в нём есть одна опечатка.
#
# 1. Напишите код, который считывает с клавиатуры слово на русском языке в нижнем регистре и генерирует список всех слов, получающихся из исходного удалением одной буквы. Запишите список в текстовый файл, каждое слово на отдельной строчке. Используйте срезы:
# ```python
# i = 5
# word = "defenestration"
# print(word[:i] + word[i + 1:])
# ```
# ```
# defenstration
# ```
# и цикл, который будет перебирать все индексы слова:
# ```
# ДЛЯ КАЖДОГО индекса i В промежутке до длины слова:
#     присвоить в переменную var результат удаления символа по индексу i
#     добавить переменную var в список
# ```
#
# 2. Измените код так, чтобы кроме удаления, учитывались ещё и замены. Для этого заведите строку, содержащую все буквы русского алфавита от а до я, и два вложенных цикла: внешний перебирает все индексы слова, а внутренний &ndash; все буквы алфавита.
# ```python
# i = 5
# letter = "q"
# word = "defenestration"
# print(word[:i] + letter + word[i + 1:])
# ```
# ```
# defenqstration
# ```
# Псевдокод:
# ```
# ДЛЯ КАЖДОГО индекса i В промежутке до длины слова:
#     ДЛЯ КАЖДОЙ буквы letter В алфавите:
#         ЕСЛИ буква letter не равна символу по индексу i в слове:
#             присвоить в переменную var результат замены символа по индексу i в слове на букву letter
#             добавить переменную var в список
# ```
#
# 3. Измените код так, чтобы учитывались и вставки символов. Если в слове N букв, то в нём N + 1 позиций, на которые можно вставить буквы.
# Псевдокод:
# ```
# ДЛЯ КАЖДОГО индекса i В промежутке до длины слова + 1:
#     ДЛЯ КАЖДОЙ буквы letter В алфавите:
#         присвоить в переменную var результат вставки буквы letter в позицию i
#         добавить переменную var в список
# ```
#   ```python
# idx = 5
# letter = "q"
# word = "defenestration"
# print(word[:i] + letter + word[i:])
# ```
# ```
# defenqestration
# ```
#
# 4. Скачайте файл по ссылке: https://github.com/danakt/russian-words/raw/refs/heads/master/russian.txt
# Прочитайте его в память компьютера (кодировка cp1251). В этом файле содержатся формы слов русского языка, по одной на каждой строчке. Создайте множество (set), в которое добавьте все эти слова.
#
# 5. Измените код так, чтобы он работал по следующему алгоритму:
# ```
# прочитать слово word с клавиатуры
# ЕСЛИ слово word есть в множестве всех слов:
#     вывести на экран сообщение "Слово написано правильно!"
# ИНАЧЕ:
#     создать пустой список variants
#     по алгоритму выше перебрать все варианты
#     ДЛЯ КАЖДОГО варианта var:
#         ЕСЛИ var в множестве всех слов:
#             добавить var в список variants
#     ЕСЛИ список variants не пустой:
#         вывести на экран сообщение "Возможно, вы имели в виду:"
#         ДЛЯ КАЖДОГО варианта в списке variants:
#             вывести вариант на экран
#     ИНАЧЕ:
#         вывести на экран сообщение "Слова нет в словаре"
# ```
