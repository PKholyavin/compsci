# %% [markdown]
# #### Задание 1
#
# Напишите программу, которая вычисляет объём конуса по радиусу основания и высоте (примите $\pi=3.14$):
#
# $$ V = \frac{1}{3} \pi r^2 h$$
#
# Если хотя бы одно введённое число не положительное, нужно вывести сообщение об ошибке.

# %% [markdown]
# #### Задание 2
#
# Найдите разность произведения и суммы всех чисел от 12 до 110, которые делятся на 3, на 2, но не на 9.

# %% [markdown]
# #### Задание 3
#
# Найдите сумму квадратов всех чисел от 10 до 1000, у которых предпоследняя цифра либо 2, либо 5.

# %% [markdown]
# #### Задание 4
#
# Дан список имён пользователей и строка с доменом. Создайте список e-mail адресов вида username@domain.
#
# Используйте сложение строк.

# %%
usernames = [
    "twilight.sparkle",
    "rainbow_dash_92",
    "flutter.shy",
    "applejack_rider",
    "pinkie.pie.party",
    "rarity_glam"
]
domain = "equestria.com"

# %% [markdown]
# Составьте новый список, где будут только адреса, в которых нет нижнего подчёркивания. Используйте оператор вхождения:

# %%
# пример использования оператора вхождения
text = input("Введите текст")
if "ы" in text:
    print("Текст содержит букву ы")
else:
    print("Текст не содержит букву ы")

# %% [markdown]
# #### Задание 5
#
# Напишите программу, которая принимает целое неотрицательное число на вход и вычисляет его факториал (произведение всех чисел от 1 до этого числа). Помните, что 0! = 1.

# %% [markdown]
# #### Задание 6
#
# Напишите программу, которая принимает на вход через `input()` целое число `n` и выводит на экран "ёлочку" из звёздочек высотой `n`.
#
# ```
#          *
#         ***
#        *****
#       *******
#      *********
#     ***********
#    *************
#   ***************
#  *****************
# *******************
# ```
#
# Подсказка: чтобы получить строку из `n` одинаковых символов, достаточно умножить строку с этим символом на `n`.

# %% [markdown]
# #### Задание 7
#
# Даны список имён людей и список их возрастов. Для каждого человека выведите на экран текст: `"NAME is AGE years old"`.

# %%
names = ["John", "Bill", "Jane", "Kate", "Mary"]
ages = [23, 25, 19, 34, 29]

# %% [markdown]
# #### Задание 8
#
# Дано логическое уравнение:
#
# $$ \overline{(A + B)} + B \cdot C \cdot D = 1 $$
#
# Найдите все его решения. Для этого:
# 1. Создайте пустой список `solutions`
# 2. Задайте четыре вложенных цикла по переменным `a, b, c` и `d`.
# 3. Для каждой комбинации `a, b, c, d` вычислите значение выражения
# 4. Если выражение равно 1, добавьте в список `solutions` список `[a, b, c, d]`.
# 5. Выведите список `solutions` на экран построчно.

# %% [markdown]
# #### Задание 9
#
# Специалист минпросвета придумывает предметы на будущий учебный год. Заведите пустой список и в бесконечном цикле спрашивайте пользователя, что он хочет сделать.
#
# * Если он отвечает "new subject", пусть введёт название предмета, который хочет добавить. Тогда добавьте его в список и выведите сообщение об этом.
#
# * Если отвечает "delete subject", проверьте, есть ли такой предмет в списке (оператор вхождения `in`). Если есть, уберите его с помощью метода `.remove()` и выведите сообщение об этом. Если нет, выведите сообщение, что такого предмета нет.
#
# * Если отвечает "show subjects", напечатайте список на экран.
#
# * Если отвечает "show number of subjects", напечатайте количество предметов.
#
# * Если отвечает "quit", остановите цикл.

# %% [markdown]
# #### Задание 10
#
# Напишите программу для решения квадратных уравнений. Пусть пользователь вводит коэффициенты a, b, c. Вычислите дискриминант и найдите корни, если они есть.
