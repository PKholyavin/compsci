# %% [markdown]
# ### Задание 1
#
# 1. Пусть пользователь введёт квадрат из целых чисел 3х3, по 3 числа на каждой строке. В строке числа разделяются пробелами. Определите, является ли квадрат магическим (т.е. сумма чисел по всем вертикалям, горизонталям, диагоналям одинакова). Создайте список из трёх списков, в который поместите числа квадрата, и используйте циклы для проверки.
#
# Пример магического квадрата:
# ```
# 8 1 6
# 3 5 7
# 4 9 2
# ```

# %% [markdown]
# 2. Измените код так, чтобы сначала пользователь вводил размер своего квадрата, а потом все строчки (т.е. чтобы поддерживались квадраты не только 3х3, но и 4х4, 5х5 и т.д.)

# %% [markdown]
# ### Задание 2
#
# Напишите программу, которая принимает на вход два слова на русском языке и определяет, заканчивается ли первое слово на то же сочетание букв, на которое начинается второе слово. Если это так, то программа должна напечатать слово, получившееся из наложения этих двух слов. В противном случае выведите сообщение об этом. Например: "шлакоблок", "окунь" -> "шлакоблокунь".
# Если такое слово можно построить несколькими способами, нужно выбрать то, у которого самое длинное наложение. Например: "катана", "ананас" -> "катананас"
#
# Алгоритм:
# Переберите все окончания первого слова с помощью цикла и срезов (всё слово; всё слово без первой буквы; всё слово, кроме первых двух букв; ...). Для определения того, начинается ли слово на последовательность букв, используйте метод `.startswith()`:
#
# ```python
# text = "hello world"
# if text.startswith("he"):
#     print("hehe")
# else:
#     print("not hehe")
# ```
# ```
# hehe
# ```

# %% [markdown]
# ### Задание 3
#
# 1. Напишите программу, которая загадывает случайное целое число от 1 до 100 и просит пользователя угадать это число. Если догадка пользователя равна загаданному числу, напечатайте об этом сообщение и завершите игру. В противном случае пусть программа выведет сообщение о том, больше ли загаданное число догадки пользователя или меньше. Для получения случайного числа используйте модуль `random` и функцию `randint()`:
#
# ```python
# import random  # это должна быть самая перва строчка вашей программы
#
# number = random.randint(1, 100)
#
# Используйте бесконечный цикл (`while True`)
# ```
#
# 2. Измените программу так, чтобы у пользователя было только ограниченное число попыток (например, 10).

# %% [markdown]
# ### Задание 4
#
# Напишите программу, которая принимает целое неотрицательное число на вход и вычисляет его факториал (произведение всех чисел от 1 до этого числа). Помните, что 0! = 1.

# %% [markdown]
# ### Задание 5
#
# Напишите программу для решения квадратных уравнений. Пусть пользователь вводит коэффициенты a, b, c. Вычислите дискриминант и найдите корни, если они есть.

# %% [markdown]
# ### Задание 6
#
# 1. Пользователь вводит координаты двух векторов на плоскости, по одному на каждой строчке. В каждой строчке числа разделены пробелом. Определите косинус угла между ними через скалярное произведение:
#
# $$
#
# \cos(\theta) = \frac{A \cdot B}{\lVert A \rVert \times \lVert B \rVert}
#
# $$
#
# Скалярное произведение определите как сумму произведений абсцисс и ординат. Длину каждого вектора определите по теореме Пифагора.
#
# 2. Измените программу так, чтобы она вычисляла площадь треугольника между векторами (считайте, что координаты всегда положительные, т.е. угол всегда меньше $\frac{\pi}{2}$)
#
# $$ S = \frac{1}{2} \lVert A \rVert \lVert B \rVert \sin(\theta) $$

# %% [markdown]
# ### Задание 7
#
# Напишите программу, которая принимает на вход вещественное число a и вычисляет его квадратный корень по следующему алгоритму:
#
# 1. Заведём две промежуточные переменные:
# ```
# x = 1
# y = (x + a / x) / 2
# ```
# 2. До тех пор, пока разница между числами не станет меньше 0.0001 по модулю, будем их обновлять (y на каждом следующем шаге будет средним арифметическим между y и a / y):
# ```
# x = y
# y = (y + a / y) / 2
# ```
# 3. После этого выводим на экран y, округлённое до 4 знаков после запятой:
#
# ```
# print(round(y, 4))
# ```
