# %% [markdown]
# ### Задание 1
#
# Дан список учеников. Для каждого ученика в списке спросите пользователя, какая у него оценка по информатике, и выведите её на экран вместе с фамилией. После конца цикла выведите среднюю оценку в группе. Если она меньше 3.5, выведите сообщение об этом.
#
# Не забудьте использовать функцию `int()`, чтобы переделать полученный от пользователя текст в число.

# %%
students = [
    "Ivanov",
    "Petrov",
    "Sidorov",
    "Smirnov",
    "Kuznetsov",
    "Popov",
    "Volkov",
    "Sokolov",
    "Lebedev",
    "Kozlov",
    "Novikov",
    "Morozov"
]

# %% [markdown]
# ### Задание 2
#
# Специалист минпросвета придумывает предметы на будущий учебный год. Заведите пустой список и в бесконечном цикле спрашивайте пользователя, что он хочет сделать. Если он отвечает "new subject", пусть введёт название предмета, который хочет добавить. Тогда добавьте его в список. Если отвечает "delete subject", проверьте, есть ли такой предмет в списке (оператор вхождения `in`). Если есть, уберите его с помощью метода `.remove()`. Если отвечает "show subjects", напечатайте список на экран. Если отвечает "show number of subjects", напечатайте количество предметов. Если отвечает "quit", остановите цикл.

# %% [markdown]
# ### Задание 3
#
# 1. Напишите программу, которая загадывает случайное целое число от 1 до 100 и просит пользователя угадать это число. Если догадка пользователя равна загаданному числу, напечатайте об этом сообщение и завершите игру. В противном случае пусть программа выведет сообщение о том, больше ли загаданное число догадки пользователя или меньше. Для получения случайного числа используйте модуль `random` и функцию `randint()`:
#
# ```python
# import random  # это должна быть самая первая строчка вашей программы
#
# number = random.randint(1, 100)
#
# Используйте бесконечный цикл (`while True`)
# ```
#
# 2. Измените программу так, чтобы у пользователя было только ограниченное число попыток (например, 10).

# %% [markdown]
# ### Задание 4
#
# Напишите программу, которая принимает целое неотрицательное число на вход и вычисляет его факториал (произведение всех чисел от 1 до этого числа). Помните, что 0! = 1.
#
# Алгоритм:
#
# 1. Считать с клавиатуры число `N` и записать в переменную.
# 2. Завести новую переменную `result`, равную 1
# 3. В цикле перебрать все числа от 2 до `N` включительно (используйте `range()`)
# 4. Умножить `result` на каждое число и присвоить результат умножения обратно в `result`
# 5. Вывести результат на экран.

# %% [markdown]
# ### Задание 5
#
# Напишите программу для решения квадратных уравнений. Пусть пользователь вводит коэффициенты a, b, c. Вычислите дискриминант и найдите корни, если они есть.
